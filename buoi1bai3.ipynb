# %%
from PIL import Image
from image_tool import *

# %%
dir = os.getcwd()
print(dir)
my_img = dir + "/img/img (1).jpg"
img = load_image(my_img)
display(img)
newSize = (256,256)
## thay đổi kích thước resize
img_new = img.resize(newSize)

img_new.save("new_img.jpg")
display(img_new)
# Out:
# C:\Users\ADMIN\Documents\Python
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=512x384>
# <PIL.Image.Image image mode=RGB size=256x256>
